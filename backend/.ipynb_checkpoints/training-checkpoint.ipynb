# %% [markdown]
# # Import the essentials

# %%
# Imports here
from __future__ import print_function, division
import numpy as np
import matplotlib.pyplot as plt
from torch.utils import data
import torch
from torch import nn
from torch import optim
import torchvision
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision.models as models
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
from skimage import io, transform
import torch.utils.data as data_utils
from PIL import Image, ImageFile
import json
from torch.optim import lr_scheduler
import time
import os
import argparse
import copy
import pandas as pd
ImageFile.LOAD_TRUNCATED_IMAGES = True
import cv2
# Import useful sklearn functions
import sklearn
from sklearn.metrics import cohen_kappa_score, accuracy_score

import time
from tqdm import tqdm_notebook

import os
print(os.listdir("/home/kasinadhsarma/dr-detection/backend"))
base_dir = "/home/kasinadhsarma/dr-detection/backend"
# Out:
# ['api.py', 'train', 'pipeline.py', 'dr_service.log', 'config.py', 'run.sh', 'sample', '__init__.py', 'test', 'data', 'main.py', 'setup.sh', 'prepare_data.py', 'Single_test_inference.ipynb', '.ipynb_checkpoints', 'model', 'models', 'train.py', 'training.ipynb', 'plot_accuracy.py', '__pycache__', 'utils.py', 'requirements.txt']

# %%
print(os.listdir("/home/kasinadhsarma/dr-detection/backend"))
# Out:
# ['api.py', 'train', 'pipeline.py', 'dr_service.log', 'config.py', 'run.sh', 'sample', '__init__.py', 'test', 'data', 'main.py', 'setup.sh', 'prepare_data.py', 'Single_test_inference.ipynb', '.ipynb_checkpoints', 'model', 'models', 'train.py', 'training.ipynb', 'plot_accuracy.py', '__pycache__', 'utils.py', 'requirements.txt']

# %%
import seaborn as sns

# %% [markdown]
# # Loading Data + EDA

# %%
train_path = os.path.join(base_dir, 'models/training_history.csv')
test_path = os.path.join(base_dir, 'models/sample.csv')

if os.path.exists(train_path) and os.path.getsize(train_path) > 0:
	train_csv = pd.read_csv(train_path)
else:
	print(f"{train_path} is empty. Creating empty DataFrame for train_csv.")
	# Get all image files from train directory, including jpeg files
	train_images = [f.split('.')[0] for f in os.listdir(os.path.join(base_dir, 'train')) 
				   if f.endswith(('.png', '.jpeg', '.jpg'))]
	
	train_csv = pd.DataFrame({
		'id_code': train_images,
		'diagnosis': np.random.randint(0, 5, len(train_images))  # 0-4 for different DR stages
	})

if os.path.exists(test_path) and os.path.getsize(test_path) > 0:
	test_csv = pd.read_csv(test_path)
else:
	print(f"{test_path} is empty. Creating empty DataFrame for test_csv.")
	# Get all image files from sample directory, including jpeg files
	test_images = [f.split('.')[0] for f in os.listdir(os.path.join(base_dir, 'sample')) 
				  if f.endswith(('.png', '.jpeg', '.jpg'))]
	
	test_csv = pd.DataFrame({
		'id_code': test_images
	})

print(f"Training set size: {len(train_csv)} images")
print(f"Test set size: {len(test_csv)} images")
# Out:
# Training set size: 10 images
# Test set size: 10 images

# %%
print('Train Size = {}'.format(len(train_csv)))
print('Public Test Size = {}'.format(len(test_csv)))
# Out:
# Train Size = 10
# Public Test Size = 10

# %%
train_csv.head()
# Out:
#               image_id  label
# 0   train/10_left.jpeg      0
# 1  train/10_right.jpeg      0
# 2   train/13_left.jpeg      1
# 3  train/13_right.jpeg      1
# 4   train/15_left.jpeg      2

# %%
counts = train_csv['label'].value_counts()
class_list = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferate']
mapping = {i: x for i, x in enumerate(class_list)}
counts = counts.rename(index=mapping)

plt.figure(figsize=(10,5))
sns.barplot(x=counts.index, y=counts.values, alpha=0.8, palette='bright')
plt.title('Distribution of Output Classes')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Target Classes', fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_54319/303424245.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, alpha=0.8, palette='bright')

# %% [markdown]
# # Visualizing Training Data

# %%
fig = plt.figure(figsize=(30, 6))
# display 16 images
train_imgs = os.listdir(os.path.join(base_dir, 'train'))
for idx, img in enumerate(np.random.choice(train_imgs, 16)):
    ax = fig.add_subplot(2, 16//2, idx+1, xticks=[], yticks=[])
    im = Image.open(os.path.join(base_dir, 'train', img))
    plt.imshow(im)
    # Get the severity label from train_csv
    img_id = os.path.join('train', img)
    lab = train_csv.loc[train_csv['image_id'] == img_id, 'label'].values[0]
    ax.set_title(f'Severity: {class_list[lab]}')

# %% [markdown]
# # Visualizing Test Set

# %%
fig = plt.figure(figsize=(30, 6))
# display 16 images
test_imgs = os.listdir(os.path.join(base_dir, 'sample'))
for idx, img in enumerate(np.random.choice(test_imgs, 16)):
    ax = fig.add_subplot(2, 16//2, idx+1, xticks=[], yticks=[])
    im = Image.open(os.path.join(base_dir, 'sample', img))
    plt.imshow(im)

# %% [markdown]
# # Data Processing

# %%
# Our own custom class for datasets
class CreateDataset(Dataset):
    def __init__(self, df_data, data_dir = '../input/', transform=None):
        super().__init__()
        self.df = df_data.values
        self.data_dir = data_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        img_name,label = self.df[index]
        img_path = os.path.join(self.data_dir, img_name+'.png')
        image = cv2.imread(img_path)
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
train_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.4),
    #transforms.ColorJitter(brightness=2, contrast=2),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])

# %%
test_transforms = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

# %%
train_path = "backend/train"
test_path = "backend/test"

# %%
train_data = CreateDataset(df_data=train_csv, data_dir=train_path, transform=train_transforms)
test_data = CreateDataset(df_data=test_csv, data_dir=test_path, transform=test_transforms)

# %%
valid_size = 0.2
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# %%
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64,sampler=train_sampler)
validloader = torch.utils.data.DataLoader(train_data, batch_size=64, sampler=valid_sampler)
testloader = torch.utils.data.DataLoader(test_data, batch_size=64)

# %%
print(f"training examples contain : {len(train_data)}")
print(f"testing examples contain : {len(test_data)}")

print(len(trainloader))
print(len(validloader))
print(len(testloader))
# Out:
# training examples contain : 10
# testing examples contain : 10
# 1
# 1
# 1

# %%
import os
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from PIL import Image

# Helper function to display images
def imshow(inp, title=None):
    """Imshow for Tensor."""
    if inp is None:
        print("No input tensor provided")
        return

    try:
        if torch.is_tensor(inp):
            inp = inp.numpy()
        if len(inp.shape) == 4:  # If batched input, take first image
            inp = inp[0]
        inp = inp.transpose((1, 2, 0))
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        inp = std * inp + mean
        inp = np.clip(inp, 0, 1)
        plt.figure(figsize=(10, 10))
        plt.imshow(inp)
        if title is not None:
            if isinstance(title, list):
                plt.title(' '.join(title))
            else:
                plt.title(title)
        plt.pause(0.001)
        plt.show()
    except Exception as e:
        print(f"Error in imshow: {str(e)}")

try:
    # Define directories
    print("Verifying data paths...")
    base_dir = "/home/kasinadhsarma/dr-detection/backend"
    train_dir = os.path.join(base_dir, 'train')

    # Check if directories exist
    if not os.path.exists(base_dir):
        raise FileNotFoundError(f"Base directory not found: {base_dir}")
    if not os.path.exists(train_dir):
        raise FileNotFoundError(f"Train directory not found: {train_dir}")

    # Check directory content
    train_files = os.listdir(train_dir)
    if len(train_files) == 0:
        raise FileNotFoundError("Train directory is empty.")

    print(f"Train directory content: {train_files[:5]}...")  # Show first 5 files

    # Validate files and fix .jpeg.png issues
    valid_files = []
    for file in train_files:
        file_path = os.path.join(train_dir, file)
        if file.endswith('.jpeg.png'):  # Handle incorrect extensions
            new_name = file.replace('.jpeg.png', '.jpeg')
            os.rename(file_path, os.path.join(train_dir, new_name))
            print(f"Renamed file: {file} -> {new_name}")
            file_path = os.path.join(train_dir, new_name)
        
        if not file.endswith(('.jpeg', '.jpg', '.png')):
            print(f"Skipping unsupported file format: {file}")
            continue

        try:
            with Image.open(file_path) as img:
                img.verify()
                valid_files.append(file_path)
        except Exception as e:
            print(f"Corrupted file detected: {file}, Error: {e}")

    if not valid_files:
        raise RuntimeError("No valid image files found in the train directory.")

    # Define transforms
    transform = transforms.Compose([
        transforms.Resize((224, 224)),  # Resize images
        transforms.ToTensor(),         # Convert images to Tensor
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Normalize
    ])

    # Define dataset
    train_data = datasets.ImageFolder(root=train_dir, transform=transform)

    # Create DataLoader
    trainloader = DataLoader(train_data, batch_size=32, shuffle=True, num_workers=0)

    # Get a batch of training data
    dataiter = iter(trainloader)
    images, labels = next(dataiter)

    if images is not None and len(images) > 0:
        # Convert to CPU if on GPU
        images_cpu = images.cpu() if images.is_cuda else images

        # Ensure we don't try to display more images than we have
        num_images = min(16, len(images))

        # Make grid of images
        out = torchvision.utils.make_grid(images_cpu[:num_images])  # Display up to 16 images

        # Create titles
        class_list = train_data.classes  # Get class names from the dataset
        titles = [class_list[label] for label in labels[:num_images]]
        
        # Display images
        imshow(out, title=titles)
    else:
        print("No images in batch.")

except Exception as e:
    print(f"Error loading data: {str(e)}")
    print("Please verify the following:")
    print(f"1. Base directory exists: {os.path.exists(base_dir)}")
    print(f"2. Train directory exists: {os.path.exists(train_dir)}")
    print(f"3. Train directory is not empty: {len(os.listdir(train_dir)) > 0}")
# Out:
# Verifying data paths...
# Train directory content: ['10_right.jpeg', '13_left.jpeg', '17_left.jpeg', '15_right.jpeg', '13_right.jpeg']...
# Error loading data: pic should be Tensor or ndarray. Got <class 'NoneType'>.
# Please verify the following:
# 1. Base directory exists: True
# 2. Train directory exists: True
# 3. Train directory is not empty: True
# [ WARN:0@1455.622] global loadsave.cpp:268 findDecoder imread_('backend/train/train/17_left.jpeg.png'): can't open/read file: check file path/integrity

# %%
# plotting the images of loaded batch with given fig size and frame data    
try:
	dataiter = iter(trainloader)
	images, labels = next(dataiter)
	
	if images is not None and len(images) > 0:
		grid = torchvision.utils.make_grid(images, nrow=20, padding=2)
		
		plt.figure(figsize=(20, 20))
		plt.imshow(np.transpose(grid, (1, 2, 0)))
		plt.axis('off')
		
		# Print labels with their corresponding class names
		label_names = [class_list[label.item()] for label in labels]
		print('Labels:', label_names)
	else:
		print("No images found in the batch")
except StopIteration:
	print("No more batches available in the dataloader")
except Exception as e:
	print(f"Error occurred: {str(e)}")

# %%
# ...existing code...
from PIL import Image

class CreateDataset(torch.utils.data.Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = []
        self.labels = []
        self.transform = transform

        for img_path, label in zip(image_paths, labels):
            try:
                with Image.open(img_path) as img:
                    img.verify()  # Verify image integrity
                self.image_paths.append(img_path)
                self.labels.append(label)
            except (IOError, SyntaxError) as e:
                print(f"Error loading image: {img_path}. {e}")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, index):
        img_path = self.image_paths[index]
        label = self.labels[index]
        try:
            with Image.open(img_path) as img:
                image = img.convert('RGB')  # Ensure 3 channels
        except Exception as e:
            print(f"Error loading image: {img_path}. {e}")
            # Optionally, handle the error by returning a placeholder or re-raising
            raise e

        if self.transform:
            image = self.transform(image)

        return image, label
# ...existing code...

# %%
class_names = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferative DR']

images, labels = next(iter(trainloader))
out = torchvision.utils.make_grid(images)
imshow(out, title=[class_names[x] for x in labels])

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = models.resnet152(pretrained=True) 

num_ftrs = model.fc.in_features 
out_ftrs = 5 
  
model.fc = nn.Sequential(nn.Linear(num_ftrs, 512),nn.ReLU(),nn.Linear(512,out_ftrs),nn.LogSoftmax(dim=1))

criterion = nn.NLLLoss()
optimizer = torch.optim.Adam(filter(lambda p:p.requires_grad,model.parameters()) , lr = 0.00001) 

scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)
model.to(device);

# %%
model_save_name = 'classifier.pt'
path = F"/kaggle/working/{model_save_name}"

# %%
# to unfreeze more layers 
for name,child in model.named_children():
  if name in ['layer2','layer3','layer4','fc']:
    print(name + 'is unfrozen')
    for param in child.parameters():
      param.requires_grad = True
  else:
    print(name + 'is frozen')
    for param in child.parameters():
      param.requires_grad = False

# %%
optimizer = torch.optim.Adam(filter(lambda p:p.requires_grad,model.parameters()) , lr = 0.000001) 
scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# %%
def load_model(path):
  checkpoint = torch.load(path)
  model.load_state_dict(checkpoint['model_state_dict'])
  optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
  return model

# %%
model = load_model("../input/kernel4f121f3247/classifier.pt")

# %%
model

# %%
pytorch_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Number of trainable parameters: \n{}".format(pytorch_total_params))

# %%
def train_and_test(e):
    epochs = e
    train_losses , test_losses, acc = [] , [], []
    valid_loss_min = np.Inf 
    model.train()
    print("Model Training started.....")
    for epoch in range(epochs):
      running_loss = 0
      batch = 0
      for images , labels in trainloader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs,labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        batch += 1
        if batch % 10 == 0:
            print(f" epoch {epoch + 1} batch {batch} completed") 
      test_loss = 0
      accuracy = 0
      with torch.no_grad():
        print(f"validation started for {epoch + 1}")
        model.eval() 
        for images , labels in validloader:
          images, labels = images.to(device), labels.to(device)
          logps = model(images) 
          test_loss += criterion(logps,labels) 
          ps = torch.exp(logps)
          top_p , top_class = ps.topk(1,dim=1)
          equals = top_class == labels.view(*top_class.shape)
          accuracy += torch.mean(equals.type(torch.FloatTensor))
      train_losses.append(running_loss/len(trainloader))
      test_losses.append(test_loss/len(validloader))
      acc.append(accuracy)
      scheduler.step()
      print("Epoch: {}/{}.. ".format(epoch+1, epochs),"Training Loss: {:.3f}.. ".format(running_loss/len(trainloader)),"Valid Loss: {:.3f}.. ".format(test_loss/len(validloader)),
        "Valid Accuracy: {:.3f}".format(accuracy/len(validloader)))
      model.train() 
      if test_loss/len(validloader) <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(valid_loss_min,test_loss/len(validloader))) 
        torch.save({
            'epoch': epoch,
            'model': model,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': valid_loss_min
            }, path)
        valid_loss_min = test_loss/len(validloader)    
    print('Training Completed Succesfully !')    
    return train_losses, test_losses, acc

# %%
train_losses, valid_losses, acc = train_and_test(5)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.plot(train_losses, label='train_')
plt.plot(valid_losses, label='Validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(frameon=False)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.plot(acc, label='accuracy')
plt.legend("")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.legend(frameon=False)
